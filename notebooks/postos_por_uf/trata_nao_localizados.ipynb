# %%
import os
import pandas as pd
from pathlib import Path

from dotenv import load_dotenv
load_dotenv()  # take environment variables from .env.
# Out:
# True

# %%
# base de não localizados
file_path = os.path.join(f'nao_localizados.csv')
df = pd.read_csv(file_path)
df['ESTABELECIMENTO'] = df['ESTABELECIMENTO'].str.strip().str.upper()
df
# Out:
#      UF     MUNICIPIO                                    ESTABELECIMENTO  \
# 0    AC    PORTO ACRE  UNIDADE DE SAUDE DA FAMILIA DANIEL GLENDSON DE...
# 1    AM          APUI                                       TRES ESTADOS
# 2    AM       AUTAZES              UNIDADE BASICA DE SAUDE SAO FRANCISCO
# 3    AM       AUTAZES                UNIDADE BASICA DE SAUDE ACU PURANGA
# 4    AM         BORBA  UNIDADE DE SAUDE DA FAMILIA ESF OTACIAS BATIST...
# ..   ..           ...                                                ...
# 570  TO    PEQUIZEIRO                            POSTO DE SAUDE PA JUARI
# 571  TO          PIUM            POSTO DE SAUDE DR JOAO FELIX CUNHA PIUM
# 572  TO        PUGMIL                  UNIDADE BASICA DE SAUDE DE PUGMIL
# 573  TO  RIO DOS BOIS        UBS MAE SABINA ARAUJO SILVA DE RIO DOS BOIS
# 574  TO    TOCANTINIA               POSTO DE SAUDE DR OSVALDO DIAS BRITO
#
#                                    LOGRADOURO NUMERO           BAIRRO  \
# 0    TRAVESSA DAS MARGARIDAS LOTE 25 QUADRA 2    S/N  PROJETO CAQUETA
# 1                     COMUNIDADE TRES ESTADOS    S/N          VICINAL
# 2                           COMUNIDADE MAMORI    S/N       ZONA RURAL
# 3                   COMUNIDADE DO ACU PURANGA    S/N       ZONA RURAL
# 4                          VILA FOZ DE CANUMA    S/N       ZONA RURAL
# ..                                        ...    ...              ...
# 570                                  PA JUARI    S/N       ZONA RURAL
# 571                      POVOADO CAFE DA ROCA    S/N       ZONA RURAL
# 572        RUA GOIAS ESQ COM A PARA Q 19 L 06    S/N           CENTRO
# 573   AV SENADOR QUEIROZ COM RUA 03 QD 0 LT 0      0  SETOR JABAQUARA
# 574         PROJETO ASSENTAMENTO AGUA FRIA II    S/N       ZONA RURAL
#
#                                      ENDERECO_COMPLETO  latitude  longitude  \
# 0    TRAVESSA DAS MARGARIDAS LOTE 25 QUADRA 2, PROJ...       NaN        NaN
# 1    COMUNIDADE TRES ESTADOS, VICINAL, APUI, AM, BR...       NaN        NaN
# 2    COMUNIDADE MAMORI, ZONA RURAL, AUTAZES, AM, BR...       NaN        NaN
# 3    COMUNIDADE DO ACU PURANGA, ZONA RURAL, AUTAZES...       NaN        NaN
# 4    VILA FOZ DE CANUMA, ZONA RURAL, BORBA, AM, BRASIL       NaN        NaN
# ..                                                 ...       ...        ...
# 570       PA JUARI, ZONA RURAL, PEQUIZEIRO, TO, BRASIL       NaN        NaN
# 571  POVOADO CAFE DA ROCA, ZONA RURAL, PIUM, TO, BR...       NaN        NaN
# 572  RUA GOIAS ESQ COM A PARA Q 19 L 06, CENTRO, PU...       NaN        NaN
# 573  AV SENADOR QUEIROZ COM RUA 03 QD 0 LT 0, SETOR...       NaN        NaN
# 574  PROJETO ASSENTAMENTO AGUA FRIA II, ZONA RURAL,...       NaN        NaN
#
#      address  point  cep
# 0        NaN    NaN  NaN
# 1        NaN    NaN  NaN
# 2        NaN    NaN  NaN
# 3        NaN    NaN  NaN
# 4        NaN    NaN  NaN
# ..       ...    ...  ...
# 570      NaN    NaN  NaN
# 571      NaN    NaN  NaN
# 572      NaN    NaN  NaN
# 573      NaN    NaN  NaN
# 574      NaN    NaN  NaN
#
# [575 rows x 12 columns]

# %%
# base cnes
path_folder_cnes = Path(os.getcwd()).resolve().parents[0]
print(path_folder_cnes.parent.absolute())
file_path = os.path.join(
  path_folder_cnes,
  'cnes_BASE_DE_DADOS_CNES_202208',
  'cnes_estabelecimentos_202208.csv')
df_cnes = pd.read_csv(file_path)
df_cnes['CO_CEP'] = df_cnes['CO_CEP'].astype(str)
df_cnes['NO_FANTASIA'] = df_cnes['NO_FANTASIA'].str.strip().str.upper()
df_cnes.head()
# Out:
# /home/rodrigo/projects/info_vacinas
#    CO_CNES                               NO_RAZAO_SOCIAL  \
# 0  2454203                    PREFEITURA DE SANTA HELENA
# 1  2289105  SECRETARIA MUNICIPAL DE SAUDE DE BARRA MANSA
# 2  2292483                 SECRETARIA MUNICIPAL DE SAUDE
# 3  2516608         PREFEITURA MUNICIPAL DE GUAJARA MIRIM
# 4  2372762                      MATERNIDADE JOAO MOREIRA
#
#                                      NO_FANTASIA          NO_LOGRADOURO  \
# 0                              PS DE BOM QUE DOI    POVOADO BOM QUE DOI
# 1  CONS ODONTOLOGICO COL MUN INDEPENDENCIA E LUZ             RUA QUATRO
# 2         UNIDADE BASICA DE SAUDE DE AGUA QUENTE      ESTRADA RIO BAHIA
# 3       PS FRANCISCA EUNICE MACIEL GUAJARA MIRIM        AVENIDA GUAPORE
# 4                       MATERNIDADE JOAO MOREIRA  LOCALIDADE DE CAETANO
#
#   NU_ENDERECO NO_COMPLEMENTO        NO_BAIRRO    CO_CEP NU_LATITUDE  \
# 0         S/N            NaN      BOM QUE DOI  65208000         NaN
# 1         143            NaN  VALE DO PARAIBA  27350000         NaN
# 2         S/N     2 DISTRITO      AGUA QUENTE  25953000         NaN
# 3         835            NaN         PLANALTO  78957000         NaN
# 4         S/N            NaN       ZONA RURAL  62840000         NaN
#
#   NU_LONGITUDE
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# base geonames
path_folder_cnes = Path(os.getcwd()).resolve().parents[0]
print(path_folder_cnes.parent.absolute())
file_path = os.path.join(
  path_folder_cnes,
  'geonames_BR',
  'BR.txt')

columns = [
  'country_code',
  'postal_code',
  'city',
  'state',
  'nao_usado_1',
  'nao_usado_2',
  'nao_usado_3',
  'nao_usado_4',
  'nao_usado_5',
  'latitude',
  'longitude',
  'nao_usado_6'
]  
df_geonames = pd.read_csv(file_path, sep='\t', names=columns)

df_geonames = df_geonames[[
  'postal_code', 'city', 'state', 'latitude', 'longitude'
]]

df_geonames['postal_code'] = df_geonames['postal_code'].str.strip()
df_geonames['postal_code'] = df_geonames['postal_code'].str.replace('-', '', regex=False)
df_geonames.head()
# Out:
# /home/rodrigo/projects/info_vacinas
#   postal_code          city state  latitude  longitude
# 0    69945000    Acrelândia  Acre   -9.9805   -66.8439
# 1    69935000  Assis Brasil  Acre  -10.8833   -70.0131
# 2    69932000     Brasiléia  Acre  -10.7677   -69.0114
# 3    69923000        Bujari  Acre   -9.5786   -68.1720
# 4    69922000      Capixaba  Acre  -10.4878   -67.8483

# %%
# liga a base de não localizados com a cnes
df = df.merge(df_cnes, how='left', left_on='ESTABELECIMENTO', right_on='NO_FANTASIA')
df
# Out:
#          UF     MUNICIPIO                                    ESTABELECIMENTO  \
# 0        AC    PORTO ACRE  UNIDADE DE SAUDE DA FAMILIA DANIEL GLENDSON DE...
# 1        AM       AUTAZES              UNIDADE BASICA DE SAUDE SAO FRANCISCO
# 2        AM       AUTAZES              UNIDADE BASICA DE SAUDE SAO FRANCISCO
# 3        AM       AUTAZES              UNIDADE BASICA DE SAUDE SAO FRANCISCO
# 4        AM       AUTAZES              UNIDADE BASICA DE SAUDE SAO FRANCISCO
# ...      ..           ...                                                ...
# 1170750  TO    PEQUIZEIRO                            POSTO DE SAUDE PA JUARI
# 1170751  TO          PIUM            POSTO DE SAUDE DR JOAO FELIX CUNHA PIUM
# 1170752  TO        PUGMIL                  UNIDADE BASICA DE SAUDE DE PUGMIL
# 1170753  TO  RIO DOS BOIS        UBS MAE SABINA ARAUJO SILVA DE RIO DOS BOIS
# 1170754  TO    TOCANTINIA               POSTO DE SAUDE DR OSVALDO DIAS BRITO
#
#                                        LOGRADOURO NUMERO           BAIRRO  \
# 0        TRAVESSA DAS MARGARIDAS LOTE 25 QUADRA 2    S/N  PROJETO CAQUETA
# 1                               COMUNIDADE MAMORI    S/N       ZONA RURAL
# 2                               COMUNIDADE MAMORI    S/N       ZONA RURAL
# 3                               COMUNIDADE MAMORI    S/N       ZONA RURAL
# 4                               COMUNIDADE MAMORI    S/N       ZONA RURAL
# ...                                           ...    ...              ...
# 1170750                                  PA JUARI    S/N       ZONA RURAL
# 1170751                      POVOADO CAFE DA ROCA    S/N       ZONA RURAL
# 1170752        RUA GOIAS ESQ COM A PARA Q 19 L 06    S/N           CENTRO
# 1170753   AV SENADOR QUEIROZ COM RUA 03 QD 0 LT 0      0  SETOR JABAQUARA
# 1170754         PROJETO ASSENTAMENTO AGUA FRIA II    S/N       ZONA RURAL
#
#                                          ENDERECO_COMPLETO  latitude_x  \
# 0        TRAVESSA DAS MARGARIDAS LOTE 25 QUADRA 2, PROJ...         NaN
# 1        COMUNIDADE MAMORI, ZONA RURAL, AUTAZES, AM, BR...         NaN
# 2        COMUNIDADE MAMORI, ZONA RURAL, AUTAZES, AM, BR...         NaN
# 3        COMUNIDADE MAMORI, ZONA RURAL, AUTAZES, AM, BR...         NaN
# 4        COMUNIDADE MAMORI, ZONA RURAL, AUTAZES, AM, BR...         NaN
# ...                                                    ...         ...
# 1170750       PA JUARI, ZONA RURAL, PEQUIZEIRO, TO, BRASIL         NaN
# 1170751  POVOADO CAFE DA ROCA, ZONA RURAL, PIUM, TO, BR...         NaN
# 1170752  RUA GOIAS ESQ COM A PARA Q 19 L 06, CENTRO, PU...         NaN
# 1170753  AV SENADOR QUEIROZ COM RUA 03 QD 0 LT 0, SETOR...         NaN
# 1170754  PROJETO ASSENTAMENTO AGUA FRIA II, ZONA RURAL,...         NaN
#
#          longitude_x  address  ...  NO_COMPLEMENTO             NO_BAIRRO  \
# 0                NaN      NaN  ...   NUCLEO URBANO       PROJETO CAQUETA
# 1                NaN      NaN  ...             NaN                CENTRO
# 2                NaN      NaN  ...             NaN             SINDICATO
# 3                NaN      NaN  ...             NaN         SAO FRANCISCO
# 4                NaN      NaN  ...       QUADRA 13  RESIDENCIAL SAO FRAN
# ...              ...      ...  ...             ...                   ...
# 1170750          NaN      NaN  ...             NaN            ZONA RURAL
# 1170751          NaN      NaN  ...             NaN            ZONA RURAL
# 1170752          NaN      NaN  ...             NaN                CENTRO
# 1170753          NaN      NaN  ...             NaN       SETOR JABAQUARA
# 1170754          NaN      NaN  ...             NaN            ZONA RURAL
#
#            CO_CEP          NU_LATITUDE         NU_LONGITUDE postal_code  \
# 0        69927000   -9.746321874025648   -67.35591173171997         NaN
# 1        65720000   -4.653079918274038    -44.8516845703125    65720000
# 2        65289000               -2.043              -45.959    65289000
# 3        76300000              -15.308              -49.598    76300000
# 4        78559162              -11.864              -55.504         NaN
# ...           ...                  ...                  ...         ...
# 1170750  77730000   -8.223085927099472  -48.949434757232666    77730000
# 1170751  77570000  -10.048652248016612    -49.6393096446991    77570000
# 1170752  77603000              -10.424              -48.894    77603000
# 1170753  77655000             -09.2038             -48.3210    77655000
# 1170754  77640000               -9.564              -48.377    77640000
#
#                    city      state latitude_y longitude_y
# 0                   NaN        NaN        NaN         NaN
# 1        Igarapé Grande  Maranhao     -4.6497    -44.8390
# 2            Maracaçumé  Maranhao     -2.0211    -45.9768
# 3                 Ceres      Goias   -15.2735    -49.6445
# 4                   NaN        NaN        NaN         NaN
# ...                 ...        ...        ...         ...
# 1170750      Pequizeiro  Tocantins    -8.4098    -48.9415
# 1170751            Pium  Tocantins   -10.0740    -49.6986
# 1170752          Pugmil  Tocantins   -10.4288    -48.8556
# 1170753    Rio dos Bois  Tocantins    -9.2090    -48.4431
# 1170754      Tocantínia  Tocantins    -9.5644    -48.1871
#
# [1170755 rows x 87 columns]

# %%
# liga a base de não localizados com o geocodes
df_cnes = df_cnes.merge(df_geonames, how='left', left_on='CO_CEP', right_on='postal_code')
df_cnes
# Out:
#         CO_CNES                               NO_RAZAO_SOCIAL  \
# 0       2454203                    PREFEITURA DE SANTA HELENA
# 1       2289105  SECRETARIA MUNICIPAL DE SAUDE DE BARRA MANSA
# 2       2292483                 SECRETARIA MUNICIPAL DE SAUDE
# 3       2516608         PREFEITURA MUNICIPAL DE GUAJARA MIRIM
# 4       2372762                      MATERNIDADE JOAO MOREIRA
# ...         ...                                           ...
# 469224  5344670                 FRANCISCO ROBERTO LELO SANTOS
# 469225  2507471    DISTRITO SANITARIO ESPECIAL INDIGENA BAHIA
# 469226  5344719                      HERNANI DOS REIS SANTANA
# 469227  2117169  PREFEITURA MUNICIPAL DE SAO JOAQUIM DE BICAS
# 469228  2146487               PREFEITURA MUNICIPAL DE IBIRACI
#
#                                              NO_FANTASIA  \
# 0                                      PS DE BOM QUE DOI
# 1          CONS ODONTOLOGICO COL MUN INDEPENDENCIA E LUZ
# 2                 UNIDADE BASICA DE SAUDE DE AGUA QUENTE
# 3               PS FRANCISCA EUNICE MACIEL GUAJARA MIRIM
# 4                               MATERNIDADE JOAO MOREIRA
# ...                                                  ...
# 469224  FRANCISCO ROBERTO LELO SANTOS CONSULTORIO MEDICO
# 469225                           POSTO DE SAUDE CARAMURU
# 469226       HERNANI DOS REIS SANTANA CONSULTORIO MEDICO
# 469227     POLICLINICA MUNICIPAL DE SAO JOAQUIM DE BICAS
# 469228                     HOSPITAL MUNICIPAL DE IBIRACI
#
#                 NO_LOGRADOURO NU_ENDERECO NO_COMPLEMENTO        NO_BAIRRO  \
# 0         POVOADO BOM QUE DOI         S/N            NaN      BOM QUE DOI
# 1                  RUA QUATRO         143            NaN  VALE DO PARAIBA
# 2           ESTRADA RIO BAHIA         S/N     2 DISTRITO      AGUA QUENTE
# 3             AVENIDA GUAPORE         835            NaN         PLANALTO
# 4       LOCALIDADE DE CAETANO         S/N            NaN       ZONA RURAL
# ...                       ...         ...            ...              ...
# 469224      RUA ALBERTO CABRE          88       SALA 303       VILA PINTO
# 469225                  RURAL           1     ZONA RURAL       MUNDO NOVO
# 469226         AV RUI BARBOSA          52        SALA 02           CENTRO
# 469227      AV MARIA DO CARMO         810            NaN  TEREZA CRISTINA
# 469228      RUA SEIS DE ABRIL         905            NaN           CENTRO
#
#           CO_CEP  NU_LATITUDE NU_LONGITUDE postal_code_x  \
# 0       65208000          NaN          NaN      65208000
# 1       27350000          NaN          NaN           NaN
# 2       25953000          NaN          NaN           NaN
# 3       78957000          NaN          NaN      78957000
# 4       62840000          NaN          NaN      62840000
# ...          ...          ...          ...           ...
# 469224  37010630  -21.5574072  -45.4430764           NaN
# 469225  45890000      -15.464      -39.651      45890000
# 469226  37002140  -21.5560717  -45.4399497           NaN
# 469227  32920000      -20.049      -44.274      32920000
# 469228  37990000   -20.463396   -47.124612      37990000
#
#                       city_x       state_x  latitude_x  longitude_x  \
# 0               Santa Helena     Maranhao      -2.4803     -45.4196
# 1                        NaN           NaN         NaN          NaN
# 2                        NaN           NaN         NaN          NaN
# 3              Guajará-Mirim      Rondonia    -11.3311     -64.4409
# 4                   Beberibe         Ceara     -4.4390     -38.0800
# ...                      ...           ...         ...          ...
# 469224                   NaN           NaN         NaN          NaN
# 469225            Pau Brasil         Bahia    -15.4432     -39.6897
# 469226                   NaN           NaN         NaN          NaN
# 469227  São Joaquim de Bicas  Minas Gerais    -20.0578     -44.2498
# 469228               Ibiraci  Minas Gerais    -20.4014     -47.1427
#
#        postal_code_y                city_y       state_y  latitude_y  \
# 0           65208000          Santa Helena     Maranhao      -2.4803
# 1                NaN                   NaN           NaN         NaN
# 2                NaN                   NaN           NaN         NaN
# 3           78957000         Guajará-Mirim      Rondonia    -11.3311
# 4           62840000              Beberibe         Ceara     -4.4390
# ...              ...                   ...           ...         ...
# 469224           NaN                   NaN           NaN         NaN
# 469225      45890000            Pau Brasil         Bahia    -15.4432
# 469226           NaN                   NaN           NaN         NaN
# 469227      32920000  São Joaquim de Bicas  Minas Gerais    -20.0578
# 469228      37990000               Ibiraci  Minas Gerais    -20.4014
#
#         longitude_y
# 0          -45.4196
# 1               NaN
# 2               NaN
# 3          -64.4409
# 4          -38.0800
# ...             ...
# 469224          NaN
# 469225     -39.6897
# 469226          NaN
# 469227     -44.2498
# 469228     -47.1427
#
# [469229 rows x 20 columns]
