# %%
pip install pycep-correios
# Out:
# ...
#      |████████████████████████████████| 100 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 58.2 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 41 kB 550 kB/s
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
#import pycep_correios
#from pycep_correios import get_address_from_cep, WebService
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import pandas as pd


# endereco = pycep_correios.get_address_from_cep('03987-110', webservice=WebService.APICEP)
#print(endereco)


UBS = pd.read_csv('/content/drive/MyDrive/info_vacinas/postos_de_saude_SP.csv', delimiter=";")
print(UBS.head())
geolocator = Nominatim(user_agent="test_app")
# location = geolocator.geocode(endereco['logradouro'] + ", " + endereco['cidade'])
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1.5)
# location = geolocator.geocode('Av 25 de agosto, Cruzeiro do Sul, AC, brazil')
#print(location.latitude, location.longitude)
UBS['END_GEO'] = UBS['END_COMPLETO'].apply(geocode)
# Out:
#    UF   MUNICÍPIO        ESTABELECIMENTO                   LOGRADOURO NÚMERO  \
# 0  SP  ADAMANTINA      UBS NOVE DE JULHO            RUA NOVE DE JULHO    841
# 1  SP  ADAMANTINA             UBS DORIGO    R DEOLINDA FERREIRA SILVA    S/N
# 2  SP  ADAMANTINA        UBS VILA JARDIM       ALAMEDA DAS MARGARIDAS    S/N
# 3  SP  ADAMANTINA       UBS PARQUE CECAP  R PROF NOEMIA BUENO DO VALE    145
# 4  SP  ADAMANTINA  UBS JARDIM ADAMANTINA                 JOAO PERRONE    S/N
#
#               BAIRRO                                       END_COMPLETO
# 0             CENTRO    RUA NOVE DE JULHO, 841,ADAMANTINA - SP - BRAZIL
# 1    ESTANCIA DORIGO  R DEOLINDA FERREIRA SILVA, ADAMANTINA - SP - B...
# 2        VILA JARDIM   ALAMEDA DAS MARGARIDAS, ADAMANTINA - SP - BRAZIL
# 3       PARQUE CECAP  R PROF NOEMIA BUENO DO VALE, 145,ADAMANTINA - ...
# 4  JARDIM ADAMANTINA             JOAO PERRONE, ADAMANTINA - SP - BRAZIL
# ...

# %%
location = geolocator.geocode('RUA NOVE DE JULHO, 841,ADAMANTINA - SP - BRAZIL')
print(location)
# Out:
# None

# %%
UBS['point'] = UBS['END_GEO'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
UBS.to_csv("/content/drive/MyDrive/info_vacinas/postos_resultSP.csv", encoding = 'utf-8')

# %%
pip install geopy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from geopy.geocoders import TomTom
from geopy.extra.rate_limiter import RateLimiter
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/info_vacinas/postos_n_enc.csv', delimiter=";")
#print(UBS.head())
geolocator = TomTom(api_key='wvuAFmBut64DLjQqey19XtfuMXZilzbj', user_agent="None")
# location = geolocator.geocode(endereco['logradouro'] + ", " + endereco['cidade'])
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
# location = geolocator.geocode('Av 25 de agosto, Cruzeiro do Sul, AC, brazil')
#print(location.latitude, location.longitude)
df['END_GEO'] = df['END_COMPLETO'].apply(geocode)
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('PC JOSE ROBERTO M TEIXEIRA, 47,SAO SEBASTIAO DA GRAMA - SP - BRAZIL',), **{}).
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/geopy/geocoders/base.py", line 344, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/usr/lib/python3.7/urllib/request.py", line 543, in _open
#     '_open', req)
#   File "/usr/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python3.7/urllib/request.py", line 1393, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/usr/lib/python3.7/urllib/request.py", line 1353, in do_open
#     r = h.getresponse()
#   File "/usr/lib/python3.7/http/client.py", line 1373, in getresponse
#     response.begin()
# ...

# %%
df['point'] = df['END_GEO'].apply(lambda loc: tuple(loc.point) if loc else None)
df.to_csv("/content/drive/MyDrive/info_vacinas/postos_SPTomTom.csv", encoding = 'utf-8')

# %%
df.to_excel("/content/drive/MyDrive/info_vacinas/postos_SPTomTom.xlsx", encoding = 'utf-8')
